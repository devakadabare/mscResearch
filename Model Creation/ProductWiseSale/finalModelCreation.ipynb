# %%
import pandas as pd

# Load the data
file_path = 'saleData.csv'
sales_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe and its info to understand its structure
sales_data.head(), sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userid        80000 non-null  int64
#  1   productname   80000 non-null  object
#  2   saleDate      80000 non-null  object
#  3   pricePerItem  80000 non-null  int64
#  4   qty           80000 non-null  int64
#  5   discount      80000 non-null  float64
#  6   totalPrice    80000 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.3+ MB
# (   userid                             productname    saleDate  pricePerItem  \
#  0       1    COLMANS N/COCONUT WATER VINEGR 350ML  2022-01-01           223
#  1       1                 MCCURRIE FENUGREEK 100G  2022-01-02           151
#  2       1         SPINNER CAFFEINATED DRINK 250ML  2022-01-02           344
#  3       1  RITZBURY SUGAR FREE DARK CHOCOLATE 45G  2022-01-02            99
#  4       1        HARISCHANDRA MASALA PAPPADAM 70G  2022-01-02           142
#
#     qty  discount  totalPrice
#  0    4       0.0         892
#  1    3       0.0         453
#  2    4       0.0        1376
#  3    4       0.0         396
#  4    4       0.0         568  ,
#  None)

# %%
# Convert 'saleDate' to datetime format
sales_data['saleDate'] = pd.to_datetime(sales_data['saleDate'])

# Create the weighted sales feature
sales_data['weightedSales'] = 0.6 * sales_data['qty'] + 0.4 * sales_data['totalPrice']

# Check the updated DataFrame
sales_data.head()
# Out:
#    userid                             productname   saleDate  pricePerItem  \
# 0       1    COLMANS N/COCONUT WATER VINEGR 350ML 2022-01-01           223
# 1       1                 MCCURRIE FENUGREEK 100G 2022-01-02           151
# 2       1         SPINNER CAFFEINATED DRINK 250ML 2022-01-02           344
# 3       1  RITZBURY SUGAR FREE DARK CHOCOLATE 45G 2022-01-02            99
# 4       1        HARISCHANDRA MASALA PAPPADAM 70G 2022-01-02           142
#
#    qty  discount  totalPrice  weightedSales
# 0    4       0.0         892          359.2
# 1    3       0.0         453          183.0
# 2    4       0.0        1376          552.8
# 3    4       0.0         396          160.8
# 4    4       0.0         568          229.6

# %%
import pandas as pd

# Convert 'saleDate' to datetime format and create a 'ds' column for Prophet
sales_data['saleDate'] = pd.to_datetime(sales_data['saleDate'])
sales_data['ds'] = sales_data['saleDate'].dt.to_period('M').dt.start_time

# Aggregate sales data by product and month
monthly_sales = sales_data.groupby(['productname', 'ds']).agg(
    y=('weightedSales', 'sum')).reset_index()

# Sort the data by 'ds' for correct chronological splitting
monthly_sales = monthly_sales.sort_values(by='ds')

# Split the data into training and testing sets (80% training, 20% testing)
split_index = int(len(monthly_sales) * 0.8)
train_data = monthly_sales.iloc[:split_index]
test_data = monthly_sales.iloc[split_index:]

# %%
from prophet import Prophet

models = {}

# Train a model for each product
for product in train_data['productname'].unique():
    product_data = train_data[train_data['productname'] == product]
    model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
    model.fit(product_data[['ds', 'y']])
    models[product] = model
# Out:
# 09:21:45 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:46 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:21:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:21:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:41 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:41 - cmdstanpy - INFO - Chain [1] start processing
# 09:22:53 - cmdstanpy - INFO - Chain [1] done processing
# 09:22:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:06 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:06 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:19 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:46 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:23:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:06 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:20 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:42 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:42 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:43 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:43 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:24:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:24:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:10 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:10 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:11 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:11 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:12 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:12 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:14 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:16 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:42 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:42 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:43 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:43 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:44 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:44 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:45 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:45 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:25:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:25:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:00 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:13 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:13 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:14 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:41 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:41 - cmdstanpy - INFO - Chain [1] start processing
# 09:26:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:20 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:27:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:27:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:41 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:41 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:53 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:28:58 - cmdstanpy - INFO - Chain [1] done processing
# 09:28:58 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:42 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:42 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:43 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:43 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:43 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:44 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:44 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:45 - cmdstanpy - INFO - Chain [1] start processing
# 09:29:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:29:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:00 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:12 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:13 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:30:53 - cmdstanpy - INFO - Chain [1] done processing
# 09:30:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:18 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:18 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:18 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:18 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:31:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:00 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:14 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:55 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:32:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:32:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:04 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:16 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:18 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:18 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:20 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:33:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:16 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:30 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:30 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:45 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:45 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:58 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:58 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:59 - cmdstanpy - INFO - Chain [1] done processing
# 09:34:59 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:12 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:12 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:16 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:20 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:41 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:41 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:35:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:35:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:14 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:36:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:36:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:05 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:06 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:06 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:33 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:46 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:46 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:55 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:58 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:58 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:00 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:13 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:13 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:14 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:19 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:19 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:20 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:51 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:51 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:38:59 - cmdstanpy - INFO - Chain [1] done processing
# 09:38:59 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:11 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:11 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:38 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:38 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:54 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:54 - cmdstanpy - INFO - Chain [1] start processing
# 09:39:55 - cmdstanpy - INFO - Chain [1] done processing
# 09:39:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:08 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:08 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:29 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:29 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:53 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:55 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:40:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:40:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:05 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:18 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:18 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:44 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:44 - cmdstanpy - INFO - Chain [1] start processing
# 09:41:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:41:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:12 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:12 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:38 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:38 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:44 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:44 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:42:58 - cmdstanpy - INFO - Chain [1] done processing
# 09:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:03 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:03 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:42 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:42 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:55 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:55 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:57 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:57 - cmdstanpy - INFO - Chain [1] start processing
# 09:43:58 - cmdstanpy - INFO - Chain [1] done processing
# 09:43:58 - cmdstanpy - INFO - Chain [1] start processing
# 09:44:10 - cmdstanpy - INFO - Chain [1] done processing
# 09:44:11 - cmdstanpy - INFO - Chain [1] start processing
# 09:44:12 - cmdstanpy - INFO - Chain [1] done processing
# 09:44:12 - cmdstanpy - INFO - Chain [1] start processing
# 09:44:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:44:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:44:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:44:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:44:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:44:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:03 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:03 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:09 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:09 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:10 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:10 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:23 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:23 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:45:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:45:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:13 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:32 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:33 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:46 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:46 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:48 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:48 - cmdstanpy - INFO - Chain [1] start processing
# 09:46:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:46:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:04 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:05 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:10 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:10 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:15 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:16 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:16 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:27 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:27 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:39 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:39 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:41 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:41 - cmdstanpy - INFO - Chain [1] start processing
# 09:47:53 - cmdstanpy - INFO - Chain [1] done processing
# 09:47:53 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:06 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:06 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:09 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:10 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:22 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:22 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:35 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:35 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:36 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:36 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:49 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:49 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:48:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:03 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:03 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:04 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:05 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:05 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:18 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:25 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:25 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 09:49:56 - cmdstanpy - INFO - Chain [1] done processing
# 09:49:56 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:13 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:14 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:26 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:26 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:28 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:40 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:50:52 - cmdstanpy - INFO - Chain [1] done processing
# 09:50:52 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:04 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:05 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:17 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:17 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:24 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:24 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:37 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:37 - cmdstanpy - INFO - Chain [1] start processing
# 09:51:50 - cmdstanpy - INFO - Chain [1] done processing
# 09:51:50 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:02 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:02 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:07 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:09 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:09 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:21 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:21 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:34 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:34 - cmdstanpy - INFO - Chain [1] start processing
# 09:52:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:52:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:53:00 - cmdstanpy - INFO - Chain [1] done processing
# 09:53:00 - cmdstanpy - INFO - Chain [1] start processing
# 09:53:01 - cmdstanpy - INFO - Chain [1] done processing
# 09:53:01 - cmdstanpy - INFO - Chain [1] start processing
# 09:53:13 - cmdstanpy - INFO - Chain [1] done processing
# 09:53:13 - cmdstanpy - INFO - Chain [1] start processing
# 09:53:15 - cmdstanpy - INFO - Chain [1] done processing
# 09:53:15 - cmdstanpy - INFO - Chain [1] start processing
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\cmdstanpy\model.py:2088, in CmdStanModel._run_cmdstan(self, runset, idx, show_progress, show_console, progress_hook, timeout)
#    2087 line = proc.stdout.readline()
# -> 2088 fd_out.write(line)
#    2089 line = line.strip()
#
# OSError: [Errno 28] No space left on device
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\cmdstanpy\model.py:2110, in CmdStanModel._run_cmdstan(self, runset, idx, show_progress, show_console, progress_hook, timeout)
#    2109     msg = 'Failed with error {}\n'.format(str(e))
# -> 2110     raise RuntimeError(msg) from e
#    2111 finally:
#
# RuntimeError: Failed with error [Errno 28] No space left on device
#
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 9
#       7 product_data = train_data[train_data['productname'] == product]
#       8 model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
# ----> 9 model.fit(product_data[['ds', 'y']])
#      10 models[product] = model
#
# File ~\anaconda3\Lib\site-packages\prophet\forecaster.py:1232, in Prophet.fit(self, df, **kwargs)
#    1230     self.params = self.stan_backend.sampling(stan_init, dat, self.mcmc_samples, **kwargs)
#    1231 else:
# -> 1232     self.params = self.stan_backend.fit(stan_init, dat, **kwargs)
#    1234 self.stan_fit = self.stan_backend.stan_fit
#    1235 # If no changepoints were requested, replace delta with 0s
#
# File ~\anaconda3\Lib\site-packages\prophet\models.py:121, in CmdStanPyBackend.fit(self, stan_init, stan_data, **kwargs)
#     118 args.update(kwargs)
#     120 try:
# --> 121     self.stan_fit = self.model.optimize(**args)
#     122 except RuntimeError as e:
#     123     # Fall back on Newton
#     124     if not self.newton_fallback or args['algorithm'] == 'Newton':
#
# File ~\anaconda3\Lib\site-packages\cmdstanpy\model.py:644, in CmdStanModel.optimize(self, data, seed, inits, output_dir, sig_figs, save_profile, algorithm, init_alpha, tol_obj, tol_rel_obj, tol_grad, tol_rel_grad, tol_param, history_size, iter, save_iterations, require_converged, show_console, refresh, time_fmt, timeout, jacobian)
#     642     dummy_chain_id = 0
#     643     runset = RunSet(args=args, chains=1, time_fmt=time_fmt)
# --> 644     self._run_cmdstan(
#     645         runset,
#     646         dummy_chain_id,
#     647         show_console=show_console,
#     648         timeout=timeout,
#     649     )
#     650 runset.raise_for_timeouts()
#     652 if not runset._check_retcodes():
#
# File ~\anaconda3\Lib\site-packages\cmdstanpy\model.py:2112, in CmdStanModel._run_cmdstan(self, runset, idx, show_progress, show_console, progress_hook, timeout)
#    2110     raise RuntimeError(msg) from e
#    2111 finally:
# -> 2112     fd_out.close()
#    2114 if not show_progress:
#    2115     get_logger().info('%s done processing', logger_prefix)
#
# OSError: [Errno 28] No space left on device

# %%
test_results = pd.DataFrame()

# Loop through each model and its corresponding product
for product, model in models.items():
    product_data = test_data[test_data['productname'] == product]
    if not product_data.empty:
        forecast = model.predict(product_data[['ds']])
        forecast['productname'] = product
        test_results = pd.concat([test_results, forecast[['ds', 'productname', 'yhat', 'yhat_lower', 'yhat_upper']]], ignore_index=True)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Calculate RMSE for each product
rmse_results = {}

rmse_items = 0;
rmse_value = 0;

for product, forecast in test_results.groupby('productname'):
    true_values = test_data[(test_data['productname'] == product) & (test_data['ds'].isin(forecast['ds']))]['y']
    rmse = np.sqrt(mean_squared_error(true_values, forecast['yhat']))
    rmse_value = rmse_value + rmse
    rmse_items = rmse_items + 1
    rmse_results[product] = rmse

# Print RMSE results
print(rmse_results)

# Print RMSE average
print(rmse_value / rmse_items)
# Out:
# {'7 UP 500ML PET': 7231.1558437479525, 'ASTRA FAT SPREAD 100G': 20534.031278729442, 'ASTRA FAT SPREAD 250G TUB': 324380.39777100936, 'ATLAS CHOOTY 11 3IN PAC ASSORTED': 2008.6216674224565, 'ATLAS CHOOTY 11 3IN PAC BLUE': 801.6573923151661, 'ATLAS CR BOOK 120 PGS SINGLE': 7362.414179738772, 'ATLAS CR BOOK 80 PGS': 7428.876901075293, 'ATLAS RULER CLEAR 6': 777.6174423823071, 'ATLAS TAPE EASY LARGE': 1885.1877150333892, 'AVOCADO JUICE': 21352.353794161263, 'AXE OIL 5ML': 13592.823482140635, 'BABY CHERAMY HERB
INT 120G': 9696.086454579294, 'CLOGARD SMART PLUS TOOTHBRUSH': 5128.80120001593, 'COCA COLA BOTTLE 400ML': 4821.648516437443, 'COCONUT': 2330.5078651209324, 'COLMANS N/COCONUT WATER VINEGR 350ML': 11896.94446105822, 'CRESCENT CHICKEN KOCHCHI BITE 14 PCS': 7722.966447222509, 'CUCUMBER': 29199.007892982117, 'DATE CROWN DATES KHALAS THERMO 250G': 1559.5211144421564, 'DELMEGE SOYA MEAT MUTTON 90G': 391.03975005302584, 'DETTOL SOAP ORIGINAL 100G': 1736.5920011337396, 'DIABETASOL NUTRI POWDER VANILLA 180G': 7802.945850052705, 'DIMO 12W DAY PIN BUY 2 SAVE 300': 4783.742885280421, 'DIMO LUMIN LED 7W DAY PIN': 19009.942333949228, 'DIVA PWER C/GUARD L-DETERGENT 600MLG': 15089.044926740578, 'DOUBLEACE SUPER SCRUBBER': 230545.0906780748, 'DOVE CONDITIONER OXYGEN MOISTU 180ML': 14060.071646452783, 'DOVE DANDRUFF CARE CONDITIONER 180ML': 30231.880623951638, 'DOVE DANDRUFF CARE SHAMPOO 180ML': 93099.49975714386, 'DOVE HEALTHY RITUAL GROW/SHAMP 180ML': 131401.44151478756, 'DOVE SHAMPO OXYGEN MOISTURE 180ML': 8514.210171338822, 'EDI ...
# 26000.219396916946

# %%
def calculate_mape(actual, predicted):
    # Remove zero values to avoid division by zero error
    mask = actual != 0
    return (np.abs(actual[mask] - predicted[mask]) / actual[mask]).mean() * 100

# Initialize a dictionary to store MAPE for each product
mape_results = {}
mape_items = 0;
mape_total_value=0;

for product, forecast in test_results.groupby('productname'):
    true_values = test_data[(test_data['productname'] == product) & (test_data['ds'].isin(forecast['ds']))]['y']
    predicted_values = forecast['yhat']
    mape = calculate_mape(true_values.values, predicted_values.values)
    mape_items = mape_items+1;
    mape_total_value = mape_total_value + mape
    mape_results[product] = mape

# Print MAPE results
print(mape_results)

# Print Mape Average
print(mape_total_value/mape_items)
# Out:
# {'7 UP 500ML PET': 543.3234777741155, 'ASTRA FAT SPREAD 100G': 1609.7484531732744, 'ASTRA FAT SPREAD 250G TUB': 7835.920092031008, 'ATLAS CHOOTY 11 3IN PAC ASSORTED': 337.46965176349414, 'ATLAS CHOOTY 11 3IN PAC BLUE': 124.52486588870669, 'ATLAS CR BOOK 120 PGS SINGLE': 626.4116181280218, 'ATLAS CR BOOK 80 PGS': 234.00797472560012, 'ATLAS RULER CLEAR 6': 488.71566986587584, 'ATLAS TAPE EASY LARGE': 427.15299989214486, 'AVOCADO JUICE': 801.0106383109028, 'AXE OIL 5ML': 433.05289551578755, 'BABY CHERAMY HERBAL CREAM 100ML': 608.2964386603795, 'BABY CHERAMY PAPER COTTON BUDS 100S': 229.5451550971264, 'BABY CHERAMY SOAP FLORAL 5*75G': 201.57511096980812, 'BABY CHERAMY SOAP POKURUWA/SADUN 5IN1': 886.4186537757744, 'BAIRAHA WHOLE CHICKEN SKINLESS': 187.17859882295457, 'BANANA - CAVENDISH': 506.1358388047351, 'BARAKA ACT FAST 5ML
KHALAS THERMO 250G': 81.73407592296262, 'DELMEGE SOYA MEAT MUTTON 90G': 72.73465398474899, 'DETTOL SOAP ORIGINAL 100G': 278.0327397970927, 'DIABETASOL NUTRI POWDER VANILLA 180G': 59.88475029548923, 'DIMO 12W DAY PIN BUY 2 SAVE 300': 20.85519486674591, 'DIMO LUMIN LED 7W DAY PIN': 287.2916313067848, 'DIVA PWER C/GUARD L-DETERGENT 600MLG': 571.2414558159625, 'DOUBLEACE SUPER SCRUBBER': 11799.641300486408, 'DOVE CONDITIONER OXYGEN MOISTU 180ML': 262.00005360159827, 'DOVE DANDRUFF CARE CONDITIONER 180ML': 1062.5413055002994, 'DOVE DANDRUFF CARE SHAMPOO 180ML': 1064.32620168736, 'DOVE HEALTHY RITUAL GROW/SHAMP 180ML': 2116.4569514935747, 'DOVE SHAMPO OXYGEN MOISTURE 180ML': 97.67416623582066,  ...
# 875.2731875235346

# %%
import os

# Define the directory path for models with high accuracy
high_accuracy_dir = 'models/highAccuracy/product'

# Create the directory if it does not already exist
os.makedirs(high_accuracy_dir, exist_ok=True)

# %%
import os
import pickle
import re

# Function to sanitize filenames by replacing or removing invalid characters
def sanitize_filename(name):
    # Replace invalid characters with an underscore or another suitable character
    return re.sub(r'[<>:"/\\|?*]', '_', name)  # Add any other characters that might cause issues

# MAPE threshold for good accuracy
good_accuracy_threshold = 100

# Export models with MAPE less than the threshold
for product, mape in mape_results.items():
    if mape < good_accuracy_threshold:
        model = models[product]
        safe_product_name = sanitize_filename(product)
        filename = os.path.join(high_accuracy_dir, f'model_{safe_product_name}.pkl')
        with open(filename, 'wb') as f:
            pickle.dump(model, f)
            print(f"Exported model for {product} with MAPE {mape}%")
# Out:
# Exported model for BFRESH DRINK NARANG 200ML with MAPE 84.37538700816067%
# Exported model for CHELLO PASTURIZED MILK 1L with MAPE 59.59562911018595%
# Exported model for CHICKEN DRUMSTICKS SKIN ON with MAPE 69.11912123727598%
# Exported model for CHILLED PIZZA LARGE - ROAST CHICKEN with MAPE 96.66974366040479%
# Exported model for CLOGARD FRESH GEL T/P LEMONGRASS 120G with MAPE 39.87020492491773%
# Exported model for DATE CROWN DATES KHALAS THERMO 250G with MAPE 81.73407592296262%
# Exported model for DELMEGE SOYA MEAT MUTTON 90G with MAPE 72.73465398474899%
# Exported model for DIABETASOL NUTRI POWDER VANILLA 180G with MAPE 59.88475029548923%
# Exported model for DIMO 12W DAY PIN BUY 2 SAVE 300 with MAPE 20.85519486674591%
# Exported model for DOVE SHAMPO OXYGEN MOISTURE 180ML with MAPE 97.67416623582066%
# Exported model for KEELLS WAFERS CHOCOLATE 100G with MAPE 99.55505986377489%
# Exported model for KIZZ SPARKLING APPLE DRINK 215ML with MAPE 50.75162384618884%
# Exported model for NATURE CHILLIE PIECES 100G with MAPE 74.00117650517748%
# Exported model for NATURE PEPPER POWDER 100G with MAPE 91.73713971589092%
# Exported model for RICH TURMERIC POWDER 50G with MAPE 83.04842713993187%
# Exported model for TASOTTI COOL BALLS ICE AQUA 25G with MAPE 60.300276782100035%
